# %%
import numpy as np

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

from sklearn.metrics import accuracy_score, f1_score

# %%
train_data = fetch_20newsgroups(
    subset='train',
    remove=('headers', 'footers', 'quotes')
)

test_data = fetch_20newsgroups(
    subset='test',
    remove=('headers', 'footers', 'quotes')
)

X_train_text = train_data.data
y_train = train_data.target

X_test_text = test_data.data
y_test = test_data.target

print("Training documents:", len(X_train_text))
print("Testing documents:", len(X_test_text))
print("Number of classes:", len(train_data.target_names))
# Out:
# Training documents: 11314
# Testing documents: 7532
# Number of classes: 20

# %%
vectorizer = CountVectorizer(
    stop_words="english",
    max_features=1000
)

X_train = vectorizer.fit_transform(X_train_text)
X_test = vectorizer.transform(X_test_text)

print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
# Out:
# Training data shape: (11314, 1000)
# Testing data shape: (7532, 1000)

# %%
mnb = MultinomialNB()

mnb.fit(X_train, y_train)

y_pred_mnb = mnb.predict(X_test)

print("Multinomial Naive Bayes completed!")
# Out:
# Multinomial Naive Bayes completed!

# %%
vectorizer_binary = CountVectorizer(
    stop_words="english",
    max_features=1000,
    binary=True
)

X_train_binary = vectorizer_binary.fit_transform(X_train_text)
X_test_binary = vectorizer_binary.transform(X_test_text)

bnb = BernoulliNB()

bnb.fit(X_train_binary, y_train)

y_pred_bnb = bnb.predict(X_test_binary)

print("Bernoulli Naive Bayes completed!")
# Out:
# Bernoulli Naive Bayes completed!

# %%
print("Multinomial Naive Bayes")
print("Accuracy:", accuracy_score(y_test, y_pred_mnb))
print("F1 Score:", f1_score(y_test, y_pred_mnb, average="weighted"))

print("\nBernoulli Naive Bayes")
print("Accuracy:", accuracy_score(y_test, y_pred_bnb))
print("F1 Score:", f1_score(y_test, y_pred_bnb, average="weighted"))
# Out:
# Multinomial Naive Bayes
# Accuracy: 0.4638874137015401
# F1 Score: 0.4534678715831128
#
# Bernoulli Naive Bayes
# Accuracy: 0.40693043016463093
# F1 Score: 0.41781753826218876

# %%
print("FINAL COMPARISON")
print("----------------------------")

print("Multinomial NB:")
print("Accuracy =", accuracy_score(y_test, y_pred_mnb))
print("F1 Score =", f1_score(y_test, y_pred_mnb, average="weighted"))

print("\nBernoulli NB:")
print("Accuracy =", accuracy_score(y_test, y_pred_bnb))
print("F1 Score =", f1_score(y_test, y_pred_bnb, average="weighted"))

print("\nConclusion:")
print("Multinomial Naive Bayes performed better than Bernoulli Naive Bayes.")
# Out:
# FINAL COMPARISON
# ----------------------------
# Multinomial NB:
# Accuracy = 0.4638874137015401
# F1 Score = 0.4534678715831128
#
# Bernoulli NB:
# Accuracy = 0.40693043016463093
# F1 Score = 0.41781753826218876
#
# Conclusion:
# Multinomial Naive Bayes performed better than Bernoulli Naive Bayes.
